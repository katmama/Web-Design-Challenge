# %%
import pandas as pd
import os

# %%
csv_path = os.path.join("Resources", "city_data.csv")

# %%
city_data = pd.read_csv(csv_path)

# %%
city_data.head()
# Out:
#    Unnamed: 0          City  Latitude  Longitude  Temperature  Humidity  \
# 0           0       Iqaluit   63.7506   -68.5145        14.70        78
# 1           1        Albany   42.6001   -73.9662        35.83        70
# 2           2  Saint-Pierre  -21.3393    55.4781        80.60        55
# 3           3   Port Alfred  -33.5906    26.8910        63.54        47
# 4           4        Luanda   -8.8368    13.2343        75.20        94
#
#    Cloudiness  Wind Speed
# 0         100       19.57
# 1          15        4.00
# 2           0        3.44
# 3           0        6.69
# 4          75        4.61

# %%
final_city_data = city_data.drop(columns=['Unnamed: 0'])

# %%
final_city_data.head()
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0       Iqaluit   63.7506   -68.5145        14.70        78         100
# 1        Albany   42.6001   -73.9662        35.83        70          15
# 2  Saint-Pierre  -21.3393    55.4781        80.60        55           0
# 3   Port Alfred  -33.5906    26.8910        63.54        47           0
# 4        Luanda   -8.8368    13.2343        75.20        94          75
#
#    Wind Speed
# 0       19.57
# 1        4.00
# 2        3.44
# 3        6.69
# 4        4.61

# %%
print(final_city_data.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Iqaluit</td>
#       <td>63.7506</td>
#       <td>-68.5145</td>
#       <td>14.70</td>
#       <td>78</td>
#       <td>100</td>
#       <td>19.57</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Albany</td>
#       <td>42.6001</td>
#       <td>-73.9662</td>
#       <td>35.83</td>
#       <td>70</td>
#       <td>15</td>
#       <td>4.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Saint-Pierre</td>
#       <td>-21.3393</td>
#       <td>55.4781</td>
#       <td>80.60</td>
#       <td>55</td>
#       <td>0</td>
#       <td>3.44</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
